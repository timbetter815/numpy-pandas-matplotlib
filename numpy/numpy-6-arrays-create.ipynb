# %% [markdown]
# # arrage
# arange 类似于Python中的 range 函数，只不过返回的不是列表，而是数组：
# arange(start, stop=None, step=1, dtype=None)
# 产生一个在区间 [start, stop) 之间，以 step 为间隔的数组，如果只输入一个参数，则默认从 0 开始，并以这个值为结束：

# %%
from numpy import *

# %%
import numpy as np
np.arange(4)
# Out:
# array([0, 1, 2, 3])

# %% [markdown]
# # linspace
# linspace(start, stop, N)
# 产生 N 个等距分布在 [start, stop]间的元素组成的数组，包括 start, stop。

# %%
linspace(1,11,3)
# Out:
# array([  1.,   6.,  11.])

# %% [markdown]
# # meshgrid
# 有时候需要在二维平面中生成一个网格，这时候可以使用 meshgrid 来完成这样的工作：

# %%
x_ticks = np.linspace(-1, 1, 5)
y_ticks = np.linspace(-1, 1, 5)
print(x_ticks)
print(y_ticks)
# Out:
# [-1.  -0.5  0.   0.5  1. ]
# [-1.  -0.5  0.   0.5  1. ]

# %%
x, y = np.meshgrid(x_ticks, y_ticks)

# %%
print(x)
print(y)
# Out:
# [[-1.  -0.5  0.   0.5  1. ]
#  [-1.  -0.5  0.   0.5  1. ]
#  [-1.  -0.5  0.   0.5  1. ]
#  [-1.  -0.5  0.   0.5  1. ]
#  [-1.  -0.5  0.   0.5  1. ]]
# [[-1.  -1.  -1.  -1.  -1. ]
#  [-0.5 -0.5 -0.5 -0.5 -0.5]
#  [ 0.   0.   0.   0.   0. ]
#  [ 0.5  0.5  0.5  0.5  0.5]
#  [ 1.   1.   1.   1.   1. ]]

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
from matplotlib import cm

def f(x, y):
    # sinc 函数
    r = np.sqrt(x ** 2 + y ** 2)
    result = np.sin(r) / r
    result[r == 0] = 1.0
    return result

x_ticks = np.linspace(-10, 10, 51)
y_ticks = np.linspace(-10, 10, 51)

x, y = np.meshgrid(x_ticks, y_ticks)

z = f(x, y)

fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')
ax.plot_surface(x, y, z,
                rstride=1, cstride=1,
                cmap=cm.YlGnBu_r)
ax.set_xlabel('x')
ax.set_ylabel('y')
ax.set_zlabel('z')
# Out:
# /Users/ttx/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:9: RuntimeWarning: invalid value encountered in true_divide
#   if __name__ == '__main__':
# Text(0.5,0,'z')
